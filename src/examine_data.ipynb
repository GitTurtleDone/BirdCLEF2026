# %%
# !pwd
# Out:
# /home/giang/Programming/AI/BirdCLEF2026/src

# %%
import pandas
train_df=pandas.read_csv('../data/train.csv')
train_df.head(10)
# Out:
#   primary_label secondary_labels type  latitude  longitude scientific_name  \
# 0       1161364               []   []  -22.7562   -46.8666    Guyalna cuta
# 1       1161364               []   []  -22.7558   -46.8700    Guyalna cuta
# 2       1161364               []   []  -22.7547   -46.8728    Guyalna cuta
# 3       1161364               []   []  -22.7547   -46.8728    Guyalna cuta
# 4       1161364               []   []  -22.7426   -46.8985    Guyalna cuta
# 5       1161364               []   []  -22.0843   -47.7327    Guyalna cuta
# 6       1161364               []   []  -20.9848   -43.7609    Guyalna cuta
# 7       1161364               []   []  -19.9674   -43.9895    Guyalna cuta
# 8       1161364               []   []  -19.8713   -43.9607    Guyalna cuta
# 9       1161364               []   []  -18.8358   -40.7354    Guyalna cuta
#
#     common_name class_name  inat_taxon_id                   author   license  \
# ...

# %%
taxonomy_df = pandas.read_csv('../data/taxonomy.csv')
taxonomy_df.head(10)
# Out:
# 5

# %%
len(train_df['label'].unique())
len(taxonomy_df['class_name'].unique())
# Out:
# 5
